# %%
import pandas as pd

from pandas_cleaning_data import new_columns_names

# %%
ndata = pd.read_csv("netflix1.csv")

# %%
ndata
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
ndata.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
ndata.drop(columns = "director")
# Out:
#      show_id     type                             title        country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#       date_added  release_year rating   duration  \
# 0      9/25/2021          2020  PG-13     90 min
# ...

# %%
ndata = ndata.drop(columns= "director")

# %%
ndata
# Out:
#      show_id     type                             title        country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#       date_added  release_year rating   duration  \
# 0      9/25/2021          2020  PG-13     90 min
# ...

# %%
ndata.columns
# Out:
# Index(['show_id', 'type', 'title', 'country', 'date_added', 'release_year',
#        'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
new_columns_names = []
for i in ndata.columns:
    new_columns_names.append(i.capitalize())

# %%
new_columns_names
# Out:
# ['Show_id',
#  'Type',
#  'Title',
#  'Country',
#  'Date_added',
#  'Release_year',
#  'Rating',
#  'Duration',
#  'Listed_in']

# %%
ndata.columns = new_columns_names

# %%
ndata
# Out:
#      Show_id     Type                             Title        Country  \
# 0         s1    Movie              Dick Johnson Is Dead  United States
# 1         s3  TV Show                         Ganglands         France
# 2         s6  TV Show                     Midnight Mass  United States
# 3        s14    Movie  Confessions of an Invisible Girl         Brazil
# 4         s8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785   s8797  TV Show                        Yunus Emre         Turkey
# 8786   s8798  TV Show                         Zak Storm  United States
# 8787   s8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788   s8784  TV Show                              Yoko       Pakistan
# 8789   s8786  TV Show                               YOM       Pakistan
#
#       Date_added  Release_year Rating   Duration  \
# 0      9/25/2021          2020  PG-13     90 min
# ...

# %%
ndata.duplicated().sum()
# Out:
# np.int64(0)

# %%
# we do not have duplicates in our data but lit it be
ndata.drop_duplicates(inplace = True)

# %%
ndata.duplicated().sum()
# Out:
# np.int64(0)

# %%
ndata.isna()
# Out:
#       Show_id   Type  Title  Country  Date_added  Release_year  Rating  \
# 0       False  False  False    False       False         False   False
# 1       False  False  False    False       False         False   False
# 2       False  False  False    False       False         False   False
# 3       False  False  False    False       False         False   False
# 4       False  False  False    False       False         False   False
# ...       ...    ...    ...      ...         ...           ...     ...
# 8785    False  False  False    False       False         False   False
# 8786    False  False  False    False       False         False   False
# 8787    False  False  False    False       False         False   False
# 8788    False  False  False    False       False         False   False
# 8789    False  False  False    False       False         False   False
#
#       Duration  Listed_in
# 0        False      False
# 1        False      False
# 2        False      False
# ...

# %%
ndata.isna().sum()
# Out:
# Show_id         0
# Type            0
# Title           0
# Country         0
# Date_added      0
# Release_year    0
# Rating          0
# Duration        0
# Listed_in       0
# dtype: int64

# %%
# we have no values that are null but if we had
#ndata.dropna(inplace=True)

# %%
ndata["Show_id"].unique()
# Out:
# array(['s1', 's3', 's6', ..., 's8801', 's8784', 's8786'],
#       shape=(8790,), dtype=object)

# %%
ndata["Show_id"].apply(lambda x: x.split("s")[1])
# Out:
# 0          1
# 1          3
# 2          6
# 3         14
# 4          8
#         ...
# 8785    8797
# 8786    8798
# 8787    8801
# 8788    8784
# 8789    8786
# Name: Show_id, Length: 8790, dtype: object

# %%
ndata["Show_id"] = ndata["Show_id"].apply(lambda x: x.split("s")[1])

# %%
ndata
# Out:
#      Show_id     Type                             Title        Country  \
# 0          1    Movie              Dick Johnson Is Dead  United States
# 1          3  TV Show                         Ganglands         France
# 2          6  TV Show                     Midnight Mass  United States
# 3         14    Movie  Confessions of an Invisible Girl         Brazil
# 4          8    Movie                           Sankofa  United States
# ...      ...      ...                               ...            ...
# 8785    8797  TV Show                        Yunus Emre         Turkey
# 8786    8798  TV Show                         Zak Storm  United States
# 8787    8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788    8784  TV Show                              Yoko       Pakistan
# 8789    8786  TV Show                               YOM       Pakistan
#
#       Date_added  Release_year Rating   Duration  \
# 0      9/25/2021          2020  PG-13     90 min
# ...

# %%
ndata["Show_id"][2]
# Out:
# np.int64(6)

# %%
type(ndata["Show_id"][4])
# Out:
# numpy.int64

# %%
ndata["Show_id"] = ndata["Show_id"].astype(int)

# %%
ndata["Date_added"] = ndata["Date_added"].apply(lambda x: x.replace("/", "-"))

# %%
ndata
# Out:
#       Show_id     Type                             Title        Country  \
# 0           1    Movie              Dick Johnson Is Dead  United States
# 1           3  TV Show                         Ganglands         France
# 2           6  TV Show                     Midnight Mass  United States
# 3          14    Movie  Confessions of an Invisible Girl         Brazil
# 4           8    Movie                           Sankofa  United States
# ...       ...      ...                               ...            ...
# 8785     8797  TV Show                        Yunus Emre         Turkey
# 8786     8798  TV Show                         Zak Storm  United States
# 8787     8801  TV Show                Zindagi Gulzar Hai       Pakistan
# 8788     8784  TV Show                              Yoko       Pakistan
# 8789     8786  TV Show                               YOM       Pakistan
#
#       Date_added  Release_year Rating   Duration  \
# 0      9-25-2021          2020  PG-13     90 min
# ...

# %%
ndata["Country"].value_counts()
# Out:
# Country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Luxembourg           1
# Senegal              1
# Belarus              1
# Puerto Rico          1
# Cyprus               1
# Name: count, Length: 86, dtype: int64

# %%
df = ndata["Country"].value_counts().reset_index()
df[df["Country"] == "United Kingdom"]
# Out:
#           Country  count
# 2  United Kingdom    638

# %%
df
# Out:
#            Country  count
# 0    United States   3240
# 1            India   1057
# 2   United Kingdom    638
# 3         Pakistan    421
# 4        Not Given    287
# ..             ...    ...
# 81      Luxembourg      1
# 82         Senegal      1
# 83         Belarus      1
# 84     Puerto Rico      1
# 85          Cyprus      1
#
# [86 rows x 2 columns]

# %%
(ndata["Country"] == "United Kingdom").sum()
# Out:
# np.int64(638)

# %%
ndata["Country"].value_counts()["Bulgaria"]
# Out:
# np.int64(5)

# %%
(ndata["Country"] == "United Kingdom").sum()
# Out:
# np.int64(638)

# %%
ndata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_id       8790 non-null   int64
#  1   Type          8790 non-null   object
#  2   Title         8790 non-null   object
#  3   Country       8790 non-null   object
#  4   Date_added    8790 non-null   object
#  5   Release_year  8790 non-null   int64
#  6   Rating        8790 non-null   object
#  7   Duration      8790 non-null   object
#  8   Listed_in     8790 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 618.2+ KB

# %%
#How many Movies vs TV Shows
ndata["Type"].value_counts()
# Out:
# Type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
ndata["Country"].value_counts().head(10)
# Out:
# Country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %%
ndata.groupby('Release_year').size().sort_values()
# Out:
# Release_year
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1925       1
# 1947       1
# 1959       1
# 1966       1
# 1961       1
# Length: 74, dtype: int64

# %%
ndata['Listed_in'].value_counts().head(10)
# Out:
# Listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Kids' TV                                            219
# Children & Family Movies                            215
# Children & Family Movies, Comedies                  201
# Documentaries, International Movies                 186
# Dramas, International Movies, Romantic Movies       180
# Name: count, dtype: int64

# %%
pd.crosstab(ndata['Country'], ndata['Type']).sort_values('Movie', ascending=False)
# Out:
# Type            Movie  TV Show
# Country
# United States    2395      845
# India             976       81
# United Kingdom    387      251
# Not Given         257       30
# Canada            187       84
# ...               ...      ...
# Jordan              0        2
# Luxembourg          0        1
# Puerto Rico         0        1
# Senegal             0        1
# Ukraine             0        2
#
# [86 rows x 2 columns]

# %%
# import pandas as pd
# from pandas_cleaning_data import new_columns_names
# ndata = pd.read_csv("netflix1.csv")
# ndata
# ndata.columns
# ndata.drop(columns = "director")
# ndata = ndata.drop(columns= "director")
# ndata
# ndata.columns
# new_columns_names = []
# for i in ndata.columns:
#     new_columns_names.append(i.capitalize())
# new_columns_names
# ndata.columns = new_columns_names
# ndata
# ndata.duplicated().sum()
# ndata.drop_duplicates(inplace = True)
# ndata.duplicated().sum()
# ndata.isna()
# ndata.isna().sum()
# ndata["Show_id"].unique()
# ndata["Show_id"].apply(lambda x: x.split("s")[1])
# ndata["Show_id"] = ndata["Show_id"].apply(lambda x: x.split("s")[1])
# ndata
# ndata["Show_id"][2]
# type(ndata["Show_id"][4])
# ndata["Show_id"] = ndata["Show_id"].astype(int)
# ndata["Date_added"] = ndata["Date_added"].apply(lambda x: x.replace("/", "-"))
# ndata
# ndata["Country"].value_counts()
# df = ndata["Country"].value_counts().reset_index()
# df[df["Country"] == "United Kingdom"]
# df
# (ndata["Country"] == "United Kingdom").sum()
# ndata["Country"].value_counts()["Bulgaria"]
# (ndata["Country"] == "United Kingdom").sum()
# ndata.info()
# ndata["Type"].value_counts()
# ndata["Country"].value_counts().head(10)
# ndata.groupby('Release_year').size().sort_values()
# ndata['Listed_in'].value_counts().head(10)
# pd.crosstab(ndata['Country'], ndata['Type']).sort_values('Movie', ascending=False)
